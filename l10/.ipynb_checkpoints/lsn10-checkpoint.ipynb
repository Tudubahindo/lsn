# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 10</span>

# %% [markdown]
# ### Exercise 10.1
#
# Choose **ONLY ONE** of the two following possibilities:
#
# 1. Parallelize with MPI libraries your Genetic Algorithm code in order to solve the TSP by performing a *Genetic Search* with (up to) 11 **parallel GA searches of the optimal path**:
# each node should perform an independent GA search, the so-called *Continent*, **but** every $N_{migr}$ generations the *Continents* should exchange their best individuals randomly.
#
# 2. Starting from your Genetic Algorithm code implement a **Parallel Tempering algorithm** (Simulated Annealing with many temperatures). Parallelize with MPI libraries your algorithm in order to solve the TSP where each computing node, up to 11, is characterized by a different temperature or a limited set of temperatures (if you need more than 11 temperatures). Use your genetic operators (except crossover) as trial moves for the Metropolis algorithm and **add a trial move that proposes an exchange of paths among adjacent temperatures (nodes)** (see lecture 8 for the acceptance formula). The candidate solution of the TSP will appear on the node with the lower temperature.

# %% [markdown]
# ### Exercise 10.2
#
# Apply your parallel code to the TSP problem for 110 italian "capoluoghi di provincia" longitude and latitude coordinates in the *cap_prov_ita.dat* file.
#
# If your choice in Exercise 10.1 is option 1, do you improve with respect using the same number of computing cores but with **independent GA searches** ?
#
# If your choice in Exercise 10.1 is option 2, by using a number of temperatures equal to the number of individuals in your **non-parallel Genetic Algorithm code**, do you "improve" with respect to it?

# %% [markdown]
# ### Solution:

# %% [markdown]
# I parallelized my genetic algorithm with MPI and applied it to the map of italian provinces:

# %%
import matplotlib
import matplotlib.pyplot as plt
import math
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt

world = gpd.read_file("provinces/ne_10m_admin_1_states_provinces.shp").to_crs(epsg=4326)
italy = world.loc[world["iso_a2"]=="IT"]
italy = italy.to_crs(epsg=4326)

map_italy = pd.read_csv('cap_prov_ita.dat', delimiter=' ', header=None, names=['x', 'y'])
geo_map_italy = gpd.GeoDataFrame(map_italy, geometry=gpd.points_from_xy(map_italy.x, map_italy.y), crs="EPSG:4326")

fig, ax = plt.subplots(figsize=(10, 10))
italy.plot(ax=ax, color='lightgrey')
italy.boundary.plot(ax=ax, edgecolor='white', linewidth=0.6)
geo_map_italy.plot(ax=ax, color='k', marker='o', markersize=10)

plt.title('Map of Italy')
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()

# %% [markdown]
# I ran my algorithm twice: the first time with 11 independent GA searches, with a population of 500 individuals and for 1000 generations. The second time I introduced a function that selects the best 50 individuals in each continent and broadcasts them to everyone else (MPI_Allgather); each continent then selects randomly 50 of these top individuals and inserts it into the population (in place of the worst 50). This function is called every 10 generations.
#
# In the previous exercise the genetic mutation and crossover operators proved effective in mixing up the population, even removing the top solution at times. To prevent the loss of the perfect path, each continent saves the best solution ever found. At the end of the search, these saved best solutions are sent to the first node and printed in an output file.

# %%
first_node = pd.read_csv('output_verbose.dat', delimiter='\t', header=None, names=['Generation', 'Check', 'L', 'AvgL', 'fit', 'trash'])
first_node_crossing = pd.read_csv('output_x_verbose.dat', delimiter='\t', header=None, names=['Generation', 'Check', 'L', 'AvgL', 'fit', 'trash'])

t = np.arange(len(first_node['Generation']))
x = np.arange(len(first_node_crossing['Generation']))
    
fig, ax = plt.subplots(1, 2, figsize=(17, 5))
ax[0].errorbar(t, first_node['L'], yerr=0, alpha=1.0, label='best')
ax[0].errorbar(t, first_node['AvgL'], yerr=0, color='green', alpha=1.0, label='average')
ax[1].errorbar(x, first_node_crossing['L'], yerr=0, alpha=1.0, label='best')
ax[1].errorbar(x, first_node_crossing['AvgL'], yerr=0, color='green', alpha=1.0, label='average')
for a in ax:
    a.set_xlabel('generation')
    a.set_ylabel('path length')
    a.grid(True)
    a.legend()
ax[0].set_title('first node, independent search')
ax[1].set_title('first node, exchange of best individuals')
plt.show()

# %% [markdown]
# The picture of the best and (top-half) average path length (for the first node) do not appear to be much different. This is probably due to the big population size. I also speculate this might be, at least partially, the untangler's fault: with a large initial population of randomly generated paths, the untangler might accidentally stumble on a path (or several) already very close, in length, to the optimal path. So sharing good paths between continents might not be so effective if everyone already has several good paths.

# %%
best_italy = pd.read_csv('output.dat', delimiter='\t', header=None)
best_italy = best_italy.iloc[:,:-1]

best_italy_x = pd.read_csv('output_x.dat', delimiter='\t', header=None)
best_italy_x = best_italy_x.iloc[:,:-1]

length = list()
length_x = list()

x = map_italy['x'].values
y = map_italy['y'].values

#print(map_italy.shape[0])

for i in range(best_italy.shape[0]):
    length.append(0)
    for j in range(map_italy.shape[0]):
        length[i] = length[i] + np.sqrt( (x[best_italy.iloc[i,j]-1] - x[best_italy.iloc[i,j-1]-1])**2 \
                                        +(y[best_italy.iloc[i,j]-1] - y[best_italy.iloc[i,j-1]-1])**2 )
        
for i in range(best_italy_x.shape[0]):
    length_x.append(0)
    for j in range(map_italy.shape[0]):
        length_x[i] = length_x[i] + np.sqrt( (x[best_italy_x.iloc[i,j]-1] - x[best_italy_x.iloc[i,j-1]-1])**2 \
                                            +(y[best_italy_x.iloc[i,j]-1] - y[best_italy_x.iloc[i,j-1]-1])**2 )
        
best_italy['L'] = length
best_italy = best_italy.sort_values('L')
best_italy = best_italy.reset_index(drop=True)

best_italy_x['L'] = length
best_italy_x = best_italy_x.sort_values('L')
best_italy_x = best_italy_x.reset_index(drop=True)
    
best = best_italy.loc[0, :].values-1
best = best[:-1]
best = best.astype(int)

best_x = best_italy_x.loc[0, :].values-1
best_x = best_x[:-1]
best_x = best_x.astype(int)

bruteforce = pd.read_csv('output_bruteforce.dat', delimiter='\t', header=None)
exact = bruteforce.loc[:, 0].values-1

fig, ax = plt.subplots(1, 3, figsize=(17, 10))

italy.plot(ax=ax[0], color='lightgrey')
italy.boundary.plot(ax=ax[0], edgecolor='white', linewidth=0.6)
geo_map_italy.plot(ax=ax[0], color='blue', marker='o', markersize=10)

for i, point in enumerate(best):
    ax[0].plot([x[point], x[best[i-1]]], [y[point], y[best[i-1]]], color='blue')

ax[0].set_title('independent search')
ax[0].set_xlabel('Longitude')
ax[0].set_ylabel('Latitude')

italy.plot(ax=ax[1], color='lightgrey')
italy.boundary.plot(ax=ax[1], edgecolor='white', linewidth=0.6)
geo_map_italy.plot(ax=ax[1], color='red', marker='o', markersize=10)

for i, point in enumerate(best_x):
    ax[1].plot([x[point], x[best_x[i-1]]], [y[point], y[best_x[i-1]]], color='red')

ax[1].set_title('exchange of best individuals')
ax[1].set_xlabel('Longitude')
ax[1].set_ylabel('Latitude')

italy.plot(ax=ax[2], color='lightgrey')
italy.boundary.plot(ax=ax[2], edgecolor='white', linewidth=0.6)
geo_map_italy.plot(ax=ax[2], color='green', marker='o', markersize=10)

for i, point in enumerate(exact):
    ax[2].plot([x[point], x[exact[i-1]]], [y[point], y[exact[i-1]]], color='green')

ax[2].set_title('exact solution')
ax[2].set_xlabel('Longitude')
ax[2].set_ylabel('Latitude')

plt.show()

L_best, L_best_x, L_exact = 0, 0, 0
for i, point in enumerate(best):
    L_best = L_best + np.sqrt( (x[point] - x[best[i-1]])**2 + (y[point] - y[best[i-1]])**2 )
for i, point in enumerate(best_x):
    L_best_x = L_best_x + np.sqrt( (x[point] - x[best_x[i-1]])**2 + (y[point] - y[best_x[i-1]])**2 )
for i, point in enumerate(exact):
    L_exact = L_exact + np.sqrt( (x[point] - x[exact[i-1]])**2 + (y[point] - y[exact[i-1]])**2 )

print('Best path length (independent):\t', L_best, '\nBest path length (exchange):\t', L_best_x, '\nOptimal path length:\t\t', L_exact)
# Out:
# Best path length (independent):	 64.5937708138155
# Best path length (exchange):	 64.62609789719366
# Optimal path length:		 64.5937708138155

# %% [markdown]
# In any case, both algortihms are very close to the exact solution (computed, just like the last time, with the Dantzig-Fulkerson-Johnson algorithm). By pure chance, the independent search finds the optimal solution, while the exchange algorithm finds a slightly longer solution.
